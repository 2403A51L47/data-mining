# %% [markdown]
# <a href="https://colab.research.google.com/github/2403A51L47/data-mining/blob/main/ADM_PROJECT_ON_REGRESSION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***REGRESSION MODELS***

# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn import datasets
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
california = datasets.fetch_california_housing()
df = pd.DataFrame(california.data,columns = california.feature_names)
df['price'] = california.target
df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  price
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %%
x = df.drop(columns='price',axis = 1)
y = df['price']
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %% [markdown]
# # **[ 1 ] Linear Regression**

# %%
lr = LinearRegression()
lr_fit = lr.fit(x_train,y_train)
lr_pred = lr.predict(x_test)

# %%
lr_mse = mean_squared_error(y_test,lr_pred)
lr_r2 = r2_score(y_test,lr_pred)
print('mse:',lr_mse)
print('r2:',lr_r2)
# Out:
# mse: 0.5289841670367209
# r2: 0.5943232652466202

# %%
plt.scatter(y_test,lr_pred, alpha=1)
plt.xlabel("actual Price")
plt.ylabel("Predicted Price")
plt.title("actual vs Predicted Values")
plt.show()

# %% [markdown]
# # **[ 2 ] SUPPORT VECTOR REGRESSION**

# %%
from sklearn.svm import SVR

# %%
svr = SVR()
svr_train = svr.fit(x_train,y_train)
svr_pred = svr.predict(x_test)

# %%
svr_mse = mean_squared_error(y_test,svr_pred)
svr_r2 = r2_score(y_test,svr_pred)
print('mse:',svr_mse)
print('r2:',svr_r2)
# Out:
# mse: 1.3260916573306467
# r2: -0.01697662624418439

# %%
plt.scatter(y_test,svr_pred, alpha=1)
plt.xlabel("actual Price")
plt.ylabel("Predicted Price")
plt.title("actual vs Predicted Values")
plt.show()

# %% [markdown]
# # **[ 3 ] RIDGE REGRESSION**

# %%
from sklearn.linear_model import Ridge

# %%
rge = Ridge()
rge_train = rge.fit(x_train,y_train)
rge_pred = rge.predict(x_test)

# %%
rge_mse = mean_squared_error(y_test,rge_pred)
rge_r2 = r2_score(y_test,rge_pred)
print('mse:',rge_mse)
print('r2:',rge_r2)
# Out:
# mse: 0.5290047234157986
# r2: 0.5943075006070294

# %%
plt.scatter(y_test,rge_pred, alpha=1)
plt.xlabel("actual Price")
plt.ylabel("Predicted Price")
plt.title("actual vs Predicted Values")
plt.show()

# %% [markdown]
# # **[ 4 ] DECISION TREE REGRESSION**

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
tree = DecisionTreeRegressor()
tree_train = tree.fit(x_train,y_train)
tree_pred = tree.predict(x_test)

# %%
tree_mse = mean_squared_error(y_test,rge_pred)
tree_r2 = r2_score(y_test,tree_pred)
print('mse:',tree_mse)
print('r2:',tree_r2)
# Out:
# mse: 0.5290047234157986
# r2: 0.5892618392302549

# %%
plt.scatter(y_test,tree_pred, alpha=1)
plt.xlabel("actual Price")
plt.ylabel("Predicted Price")
plt.title("actual vs Predicted Values")
plt.show()

# %% [markdown]
# # [ 5 ] ***Logistic Regression***

# %%
from sklearn.linear_model import LogisticRegression

# %%
lgr = DecisionTreeRegressor()
lgr_train = lgr.fit(x_train,y_train)
lgr_pred = lgr.predict(x_test)

# %%
lgr_mse = mean_squared_error(y_test,rge_pred)
lgr_r2 = r2_score(y_test,tree_pred)
print('mse:',lgr_mse)
print('r2:',lgr_r2)
# Out:
# mse: 0.5290047234157986
# r2: 0.5892618392302549

# %%
plt.scatter(y_test,lgr_pred, alpha=1)
plt.xlabel("actual price")
plt.ylabel("Predicted Price")
plt.title("actual vs Predicted Values")
plt.show()

# %%
from sklearn.linear_model import Lasso

# %%
lss = Lasso()
lss_traim = lss.fit(x_train,y_train)
lss_pred = lss.predict(x_test)

# %%
plt.scatter(y_test,lss_pred)
plt.xlabel("actual price")
plt.ylabel("Predicted Price")
# Out:
# Text(0, 0.5, 'Predicted Price')
