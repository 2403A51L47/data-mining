# %% [markdown]
# <a href="https://colab.research.google.com/github/2403A51L47/data-mining/blob/main/muliple_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
data = {'tv' : [230,44.5,17.2] ,
        'Radio' : [37.8,np.nan,45.9],
        'Newspaper':[69.2,45.1,69.3],
        'Sales' :[22.1,10.4,9.3] }

# %%
df = pd.DataFrame(data)
df
# Out:
#       tv  Radio  Newspaper  Sales
# 0  230.0   37.8       69.2   22.1
# 1   44.5    NaN       45.1   10.4
# 2   17.2   45.9       69.3    9.3

# %%
df.isnull()
# Out:
#       tv  Radio  Newspaper  Sales
# 0  False  False      False  False
# 1  False   True      False  False
# 2  False  False      False  False

# %%
df.fillna(39.3,inplace = True)

# %%
df.describe()
# Out:
#                tv      Radio  Newspaper      Sales
# count    3.000000   3.000000   3.000000   3.000000
# mean    97.233333  41.000000  61.200000  13.933333
# std    115.786715   4.309292  13.943099   7.093894
# min     17.200000  37.800000  45.100000   9.300000
# 25%     30.850000  38.550000  57.150000   9.850000
# 50%     44.500000  39.300000  69.200000  10.400000
# 75%    137.250000  42.600000  69.250000  16.250000
# max    230.000000  45.900000  69.300000  22.100000

# %%
xx = df['Radio']
yy = df['Sales']

plt.scatter(xx,yy)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df.isnull()
# Out:
#       tv  Radio  Newspaper  Sales
# 0  False  False      False  False
# 1  False  False      False  False
# 2  False  False      False  False

# %%
x = df.drop('Sales',axis=1)
y = df['Sales']

# %%
x
# Out:
#       tv  Radio  Newspaper
# 0  230.0   37.8       69.2
# 1   44.5   39.3       45.1
# 2   17.2   45.9       69.3

# %%
y
# Out:
# 0    22.1
# 1    10.4
# 2     9.3
# Name: Sales, dtype: float64

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,random_state= 2)

# %%
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %%
y_pred
# Out:
# array([8.89849268])

# %%
print(f"Coefficients : {model.coef_}")
print(f"inercept : {model.intercept_}")
# Out:
# Coefficients : [ 0.06202186 -0.00050152  0.00805783]
# inercept : 7.296329412679166

# %%
mse = mean_squared_error(y_test,y_pred)
r2 = r2_score(y_test,y_pred)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)

# %%
print(f"Mean squared error : {mse}")
print(f"R-squared : {r2}")
# Out:
# Mean squared error : 0.16120812535098447
# R-squared : nan

# %%
plt.scatter(y_test,y_pred)
plt.show()
